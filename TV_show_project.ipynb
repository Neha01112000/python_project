# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as image
import urllib.request
from PIL import Image

# %%
data_input=pd.read_csv('metacritic best tv shows of all time.csv')

# %%
data_input.head()
# Out:
#    rank                             title             release  \
# 0     1                 Rectify: Season 4    October 26, 2016
# 1     2  The Larry Sanders Show: Season 4       July 19, 1995
# 2     3              Murder One: Season 1  September 19, 1995
# 3     4  The Larry Sanders Show: Season 6      March 15, 1998
# 4     5            Breaking Bad: Season 5       July 15, 2012
#
#                                              summary  metascore userscore  \
# 0  Daniel tries to start a new life outside of Pa...         99       8.7
# 1  Comic Garry Shandling draws upon his own talk ...         99       5.8
# 2  One of several crime and law dramas created by...         99       6.4
# 3  Comic Garry Shandling draws upon his own talk ...         99       5.5
# 4  The final season for the award-winning drama b...         99       9.6
#
#                                                 link  \
# 0     https://www.metacritic.com/tv/rectify/season-4
# 1  https://www.metacritic.com/tv/the-larry-sander...
# 2  https://www.metacritic.com/tv/murder-one/season-1
# 3  https://www.metacritic.com/tv/the-larry-sander...
# 4  https://www.metacritic.com/tv/breaking-bad/sea...
#
#                                              img_url
# 0  https://static.metacritic.com/images/products/...
# 1  https://static.metacritic.com/images/products/...
# 2  https://static.metacritic.com/images/products/...
# 3  https://static.metacritic.com/images/products/...
# 4  https://static.metacritic.com/images/products/...

# %%
data_input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3084 entries, 0 to 3083
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   rank       3084 non-null   int64
#  1   title      3084 non-null   object
#  2   release    3084 non-null   object
#  3   summary    3084 non-null   object
#  4   metascore  3084 non-null   int64
#  5   userscore  3084 non-null   object
#  6   link       3084 non-null   object
#  7   img_url    3084 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 192.9+ KB

# %%
data_input.isnull().sum()
# Out:
# rank         0
# title        0
# release      0
# summary      0
# metascore    0
# userscore    0
# link         0
# img_url      0
# dtype: int64

# %%
data_input['rank'].unique()
# Out:
# array([   1,    2,    3, ..., 3082, 3083, 3084], dtype=int64)

# %%
data_input[['month','Year']]=data_input['release'].str.split(',',expand=True)

# %%
data_input.head(1)
# Out:
#    rank              title           release  \
# 0     1  Rectify: Season 4  October 26, 2016
#
#                                              summary  metascore userscore  \
# 0  Daniel tries to start a new life outside of Pa...         99       8.7
#
#                                              link  \
# 0  https://www.metacritic.com/tv/rectify/season-4
#
#                                              img_url       month   Year
# 0  https://static.metacritic.com/images/products/...  October 26   2016

# %%
urllib.request.urlretrieve('https://media.istockphoto.com/photos/online-streaming-with-tablet-pc-picture-id1208363215?k=20&m=1208363215&s=612x612&w=0&h=PX_J64hTqQpkdvc6MwUmtSrJMF1Zjj6dUMSgBKou2jo=','image.jpg')
# Out:
# ('image.jpg', <http.client.HTTPMessage at 0x20d88b65210>)

# %%
urllib.request.urlretrieve('https://images.unsplash.com/photo-1560169897-fc0cdbdfa4d5?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8MXx8dHYlMjBzaG93fGVufDB8fDB8fA%3D%3D&w=1000&q=80','image1.jpg')
# Out:
# ('image1.jpg', <http.client.HTTPMessage at 0x20d88b75090>)

# %%
urllib.request.urlretrieve('data:image/jpeg;base64,...','image2.jpg')
# Out:
# ('image2.jpg', <email.message.Message at 0x20d88b68cd0>)

# %%
urllib.request.urlretrieve('data:image/jpeg;base64,...','image3.jpg')
# Out:
# ('image3.jpg', <email.message.Message at 0x20d88b5f490>)

# %%
im = image.imread('image.jpg')

# %%
im1 = image.imread('image1.jpg')
im2 = image.imread('image2.jpg')
im3 = image.imread('image3.jpg')

# %%
# WHICH YEAR HIGHEST SCORE
yearcount = data_input.groupby('Year')['userscore'].count().reset_index()

# %%
pd.DataFrame(yearcount)
# Out:
#       Year  userscore
# 0    -0001          1
# 1     1977          1
# 2     1981          1
# 3     1982          1
# 4     1984          1
# 5     1985          1
# 6     1986          2
# 7     1987          3
# 8     1988          7
# 9     1989          5
# 10    1990         17
# 11    1991          5
# 12    1992          9
# 13    1993         16
# 14    1994         12
# 15    1995         13
# 16    1996         12
# 17    1997         13
# 18    1998         12
# 19    1999         15
# 20    2000         33
# 21    2001         21
# 22    2002         29
# 23    2003         23
# 24    2004         23
# 25    2005         72
# 26    2006        115
# 27    2007         99
# 28    2008        108
# 29    2009        108
# 30    2010        127
# 31    2011        149
# 32    2012        146
# 33    2013        180
# 34    2014        189
# 35    2015        205
# 36    2016        205
# 37    2017        200
# 38    2018        174
# 39    2019        205
# 40    2020        221
# 41    2021        230
# 42    2022         75

# %%
yearcount = yearcount.sort_values('userscore',ascending = False)
pd.DataFrame(yearcount)
# Out:
#       Year  userscore
# 41    2021        230
# 40    2020        221
# 39    2019        205
# 36    2016        205
# 35    2015        205
# 37    2017        200
# 34    2014        189
# 33    2013        180
# 38    2018        174
# 31    2011        149
# 32    2012        146
# 30    2010        127
# 26    2006        115
# 29    2009        108
# 28    2008        108
# 27    2007         99
# 42    2022         75
# 25    2005         72
# 20    2000         33
# 22    2002         29
# 24    2004         23
# 23    2003         23
# 21    2001         21
# 10    1990         17
# 13    1993         16
# 19    1999         15
# 17    1997         13
# 15    1995         13
# 18    1998         12
# 16    1996         12
# 14    1994         12
# 12    1992          9
# 8     1988          7
# 11    1991          5
# 9     1989          5
# 7     1987          3
# 6     1986          2
# 3     1982          1
# 2     1981          1
# 1     1977          1
# 4     1984          1
# 5     1985          1
# 0    -0001          1

# %%
color = ['#800000','#808000','#008000','#800080','#008080','#000080']
fig,ax = plt.subplots(figsize=(10,5))
ax=sns.barplot(x= yearcount['Year'],y=yearcount['userscore'],palette = color)
fig.figimage(im, 10, 10, zorder=3, alpha=.2 )
plt.title('Yearly Score Distripution',fontsize=20)
# Out:
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\726462579.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x= yearcount['Year'],y=yearcount['userscore'],palette = color)
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\726462579.py:3: UserWarning:
# The palette list has fewer values (6) than needed (43) and will cycle, which may produce an uninterpretable plot.
#   ax=sns.barplot(x= yearcount['Year'],y=yearcount['userscore'],palette = color)
# Text(0.5, 1.0, 'Yearly Score Distripution')

# %%
# WHICH YEAR MORE RELEASE
data_input['Year'].value_counts()
# Out:
# Year
#  2021     230
#  2020     221
#  2016     205
#  2015     205
#  2019     205
#  2017     200
#  2014     189
#  2013     180
#  2018     174
#  2011     149
#  2012     146
#  2010     127
#  2006     115
#  2009     108
#  2008     108
#  2007      99
#  2022      75
#  2005      72
#  2000      33
#  2002      29
#  2004      23
#  2003      23
#  2001      21
#  1990      17
#  1993      16
#  1999      15
#  1997      13
#  1995      13
#  1998      12
#  1994      12
#  1996      12
#  1992       9
#  1988       7
#  1989       5
#  1991       5
#  1987       3
#  1986       2
#  1981       1
#  1984       1
#  1982       1
#  1985       1
#  -0001      1
#  1977       1
# Name: count, dtype: int64

# %%
color = ['#800000','#808000','#008000','#800080','#008080','#000080']
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.barplot(x=data_input['Year'].value_counts().index,y = data_input['Year'].value_counts().values,palette = color)
fig.figimage(im1, 10, 10, zorder=3, alpha=.2 )
plt.tick_params(axis = 'x',rotation = 90)
plt.title('Yearly release Distripution',fontsize =20)
plt.xlabel('year')
# Out:
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\2202601447.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=data_input['Year'].value_counts().index,y = data_input['Year'].value_counts().values,palette = color)
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\2202601447.py:3: UserWarning:
# The palette list has fewer values (6) than needed (43) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=data_input['Year'].value_counts().index,y = data_input['Year'].value_counts().values,palette = color)
# Text(0.5, 0, 'year')

# %%
# WHICH TITLE HIGH RELEASE
title=data_input['title'].value_counts().reset_index()
title
# Out:
#                                       title  count
# 0                   The Golden Globe Awards      3
# 1                     Rollergirls: Season 1      2
# 2                         Rectify: Season 4      1
# 3                 Undercover Boss: Season 1      1
# 4     Dolly Parton's Heartstrings: Season 1      1
# ...                                     ...    ...
# 3076                I'll Fly Away: Season 1      1
# 3077              The Tick (2017): Season 1      1
# 3078                Downton Abbey: Season 4      1
# 3079             The Amazing Race: Season 1      1
# 3080       The 1/2 Hour News Hour: Season 1      1
#
# [3081 rows x 2 columns]

# %%
title = pd.DataFrame(title)
title
# Out:
#                                       title  count
# 0                   The Golden Globe Awards      3
# 1                     Rollergirls: Season 1      2
# 2                         Rectify: Season 4      1
# 3                 Undercover Boss: Season 1      1
# 4     Dolly Parton's Heartstrings: Season 1      1
# ...                                     ...    ...
# 3076                I'll Fly Away: Season 1      1
# 3077              The Tick (2017): Season 1      1
# 3078                Downton Abbey: Season 4      1
# 3079             The Amazing Race: Season 1      1
# 3080       The 1/2 Hour News Hour: Season 1      1
#
# [3081 rows x 2 columns]

# %%
title.columns=(['title','counts'])

# %%
title= title.head(10)
title
# Out:
#                                    title  counts
# 0                The Golden Globe Awards       3
# 1                  Rollergirls: Season 1       2
# 2                      Rectify: Season 4       1
# 3              Undercover Boss: Season 1       1
# 4  Dolly Parton's Heartstrings: Season 1       1
# 5               JANET JACKSON.: Season 1       1
# 6                        Smith: Season 1       1
# 7       God, the Devil and Bob: Season 1       1
# 8                Mr. Selfridge: Season 1       1
# 9                     A.P. Bio: Season 1       1

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax = sns.barplot(x=title['title'],y = title['counts'],palette = color)
fig.figimage(im, 10, 10, zorder=3, alpha=.2 )
plt.tick_params(axis = 'x',rotation = 90)
plt.title('High Release title distripution',fontsize =20)
plt.xlabel('year')
# Out:
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\1396050541.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=title['title'],y = title['counts'],palette = color)
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\1396050541.py:2: UserWarning:
# The palette list has fewer values (6) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=title['title'],y = title['counts'],palette = color)
# Text(0.5, 0, 'year')

# %%
# TOP 10 TITLE MORE METASCORE
titlemetascore = data_input.groupby('title')['metascore'].sum().reset_index()
titlemetascore
# Out:
#                                      title  metascore
# 0                       #blackAF: Season 1         61
# 1          'Til Death Do Us Part: Season 1         43
# 2                       1 vs 100: Season 1         54
# 3               10 Items Or Less: Season 1         42
# 4     10 Things I Hate About You: Season 1         66
# ...                                    ...        ...
# 3076  jeen-yuhs: A Kanye Trilogy: Season 1         71
# 3077                   mixed-ish: Season 1         70
# 3078                 neXt (2020): Season 1         58
# 3079                 quarterlife: Season 1         53
# 3080                seaQuest DSV: Season 1         51
#
# [3081 rows x 2 columns]

# %%
titlescore = titlemetascore.sort_values('metascore',ascending = False).head(10)
titlescore
# Out:
#                                  title  metascore
# 2382           The Golden Globe Awards        172
# 1565              Murder One: Season 1         99
# 2464  The Larry Sanders Show: Season 6         99
# 362             Breaking Bad: Season 5         99
# 2462  The Larry Sanders Show: Season 4         99
# 1847                 Rectify: Season 4         99
# 2567         The Office (UK): Season 1         98
# 2569         The Office (UK): Season 3         98
# 324                 Bo Burnham: Inside         98
# 2479           The Leftovers: Season 3         98

# %%
plt.pie(titlescore['metascore'],labels =titlescore['title'],colors = color )
plt.title('Top 10 Title metascore',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Top 10 Title metascore')

# %%
# Which month more release
month = data_input['month'].value_counts()
month = pd.DataFrame(month)
month
# Out:
#               count
# month
# September 22     42
# September 23     33
# September 25     32
# September 24     32
# September 20     30
# ...             ...
# December 13       1
# November 26       1
# August 29         1
# December 21       1
# December 27       1
#
# [365 rows x 1 columns]

# %%
month = month.reset_index(drop=True)  # Reset the index and drop the existing index column
month.rename(columns={'index': 'new_column_name'}, inplace=True)  # Rename the new index column
month = month.head(10)

# %%
plt.pie(month['counts'],labels = month['month'],colors = color)
plt.title('top monthly release',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'top monthly release')

# %%
# TOP 10 USER SCORE
user=data_input['userscore'].value_counts().reset_index()
user
# Out:
#    userscore  count
# 0        tbd    264
# 1        7.4     92
# 2        7.3     90
# 3        8.3     88
# 4        7.5     86
# ..       ...    ...
# 86       9.9      1
# 87       0.1      1
# 88       1.1      1
# 89       9.6      1
# 90       1.6      1
#
# [91 rows x 2 columns]

# %%
user.columns=['score','counts']

# %%
topuserscore=user.head(10)

# %%
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.barplot(x=topuserscore['score'],y = topuserscore['counts'],palette = color)
fig.figimage(im1, 10, 10, zorder=3, alpha=.2 )
plt.tick_params(axis = 'x',rotation = 90)
plt.title('TOP 10 score distripution ',fontsize =20)
plt.xlabel('Scores')
# Out:
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\296929321.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=topuserscore['score'],y = topuserscore['counts'],palette = color)
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_22208\296929321.py:2: UserWarning:
# The palette list has fewer values (6) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(x=topuserscore['score'],y = topuserscore['counts'],palette = color)
# Text(0.5, 0, 'Scores')
